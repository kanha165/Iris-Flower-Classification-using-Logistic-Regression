# %%
import pickle
import numpy as np

# %%
with open("logistic_model.pkl", "rb") as file:
    saved_data = pickle.load(file)

# %%
saved_data
# Out:
# {'model': LogisticRegression(max_iter=200, multi_class='multinomial'),
#  'scaler': StandardScaler(),
#  'label_encoder': LabelEncoder()}

# %%
model = saved_data["model"]

# %%
scaler = saved_data["scaler"]

# %%
le = saved_data["label_encoder"]
print("Model loaded successfully!\n")
# Out:
# Model loaded successfully!

# %%
print("Enter flower measurements:")
sepal_length = float(input("Sepal length (cm): "))
sepal_width  = float(input("Sepal width (cm): "))
petal_length = float(input("Petal length (cm): "))
petal_width  = float(input("Petal width (cm): "))
# Out:
# Enter flower measurements:
# Sepal length (cm):  6.2
# Sepal width (cm):  3.2
# Petal length (cm):  5.4
# Petal width (cm):  2.3

# %%
input_data = np.array([[sepal_length, sepal_width, petal_length, petal_width]])

# %%
scaled_data = scaler.transform(input_data)
# Out:
# C:\Users\Tirupati\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
prediction = model.predict(scaled_data)
predicted_species = le.inverse_transform(prediction)[0]

# %%
print("\n Predicted Species:", predicted_species)
# Out:
#  Predicted Species: Iris-virginica
